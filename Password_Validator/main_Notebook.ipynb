# %%
# Out:
# a
# s
# d
# l
# k
# n
# g
# d
# l
# s
# asdlkngdls
# ['a', 's', 'd', 'l', 'k', 'n', 'g', 'd', 'l', 's']
# ' if len(passwdLst)<8:\n    print ("password length not sufficient...")\nelif \nelse:\n    print ("Thats gooood....more than 8 is always good...")\n\n\n#print (f"hello {uname}, the password you have set is {passwd}") '
